# %%
# %%javascript
# IPython.notebook.clear_all_output();

# %%
# !pip install tweepy

# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'pk07DZSWpJPYF8Py6J8YHCtlr'
consumer_secret = 'Sju0guADPzpVcVMT0YzGHAPNAACKgTCNFWNlevwz1EjkqVxqUO'
access_token = '1234980489561354243-s0PWPFVdeWK0orTf2GSeVlpArKQzuV'
access_secret = 'cyuXC8Ybp3cKK6CntWsaArRaqYcwMxeCTw7P6eLY5ZRuT'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('opioid.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['opioid', 'morphine'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# ...

# %%
import json

file = open('opioid.json', 'r')
for line in file:
    print('============================')
    text = json.loads(line)
    formatted = json.dumps(text, indent=2)
    print(formatted)
    print()
file.close()
# Out:
# ...
# {
#   "created_at": "Sat Mar 14 17:21:13 +0000 2020",
#   "id": 1238877857830461442,
#   "id_str": "1238877857830461442",
#   "text": "RT @tammytabby: Moment Oklahoma officer collapses immediately after accidentally touching the deadly street drug fentanyl - which is 100 ti\u2026",
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "truncated": false,
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 705180372598784000,
#     "id_str": "705180372598784000",
#     "name": "Gabby\ud83c\udf1f\ud83c\udf1f\ud83c\udf1f   Rally crowds are great!",
#     "screen_name": "Gabbysings2",
#     "location": "#MAGA!   ",
#     "url": null,
#     "description": "BE THE VOTER THAT PUTS TRUMP OVER IN 2020!!  \n\nHAVE FUN AT THE RALLIES, BUT VOTE AT THE POLLS!",
# ...

# %%
import json

file = open('opioid.json', 'r')
for line in file:
    text = json.loads(line)
    print(text['id'], ":", text['text'])
file.close()
# Out:
# 1238877857830461442 : RT @tammytabby: Moment Oklahoma officer collapses immediately after accidentally touching the deadly street drug fentanyl - which is 100 ti…
# 1238877887836512256 : RT @victorykn: @NOIResearch The Jewish Family Making Billions From The Opioid Crisis A new profile in Esquire chronicles the life and busin…
# 1238877908963213312 : @robertgriffin5 @CaGueva15 @LizLiz_Di @marklevinshow Look at it this, a least he didn't have his kids with him, in… https://t.co/xDqK9SoEEY
# 1238878056892301319 : #OpioidCrisis #SuicidePrevention #BehavioralHealthProblemIceberg
#
# https://t.co/N3dSMnQPEi
#
# #HumanReasoning… https://t.co/ux0Wc8zMcd
# 1238878122038173697 : #ChoreographYourJobChanges https://t.co/GWwSuj6aLF
# 1238878641880289286 : Musicians coming together to help patients discover #music to mitigate #drug use and avoid the #opioidepidemic.… https://t.co/XgSAwBawLg
# 1238878942997745666 : RT @allentien: #OpioidCrisis #SuicidePrevention #BehavioralHealthProblemIceberg
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-055a95292193> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_json (r'opioid.json')
#       3 print (df)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# ...

# %% [markdown]
# The End
